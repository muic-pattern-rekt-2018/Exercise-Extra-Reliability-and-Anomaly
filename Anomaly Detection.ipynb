# %% [markdown]
# # Basic (1D)

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# 1) Find anomaly here.

# %%
data = np.random.randn(1000)*3 + 10
data = np.concatenate((data, [24.2]))

plt.hist(data, bins=20)
# Out:
# (array([  1.,   3.,   7.,  14.,  21.,  84.,  98., 155., 165., 156., 131.,
#          94.,  36.,  25.,   6.,   4.,   0.,   0.,   0.,   1.]),
#  array([-0.7218008 ,  0.52428924,  1.77037928,  3.01646932,  4.26255936,
#          5.5086494 ,  6.75473944,  8.00082948,  9.24691952, 10.49300956,
#         11.7390996 , 12.98518964, 14.23127968, 15.47736972, 16.72345976,
#         17.9695498 , 19.21563984, 20.46172988, 21.70781992, 22.95390996,
#         24.2       ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# 2) What is the probability of finding such a data to appear?

# %% [markdown]
# # Multiple Dimension

# %%
xs = np.random.randn(100)*2+3
ys = 2*xs + 3 + np.random.randn(100)

xs = np.concatenate([xs,[4]])
ys = np.concatenate([ys,[0]])

plt.hist2d(xs, ys, bins=20);

# %% [markdown]
# 1) Find the anomaly here. Whats the idea?
